# %% [markdown]
# Cargamos los datos obtenidos previamente

# %%
import numpy as np
import matplotlib.pyplot as plt

REAL_PHI_FILE = '../Mediciones/real_phi_interp.bin'
SIC_PHI_FILE = '../Mediciones/sic_phi.bin'

real_phi = np.fromfile(REAL_PHI_FILE)
sic_phi = np.fromfile(SIC_PHI_FILE)
sic_phi = np.round(sic_phi)

# %% [markdown]
# Calculamos la diferencia

# %%
TE = sic_phi - real_phi

# %% [markdown]
# Y a la secuencia de discrepancias de tiempos le medimos la magnitud TDEV

# %%
from allan import plotTDEV
plotTDEV(TE)
